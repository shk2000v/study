# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# d = pd.DataFrane(L/A/D)(list/array/dictionary)
#
# LAD를 꼭 외우자!!

# %%
import pandas as pd

# %%
df =pd.DataFrame({
    "name" : ["송종천","김근호","김세연"],
    "age" : [20,25,30],
    "job" : ["프로그래머", "의사", "변호사" ]
})

# %%
df
# Out:
#   name  age    job
# 0  송종천   20  프로그래머
# 1  김근호   25     의사
# 2  김세연   30    변호사

# %%
df1 = pd.DataFrame([
    {"송종천", 20 , "프로그래머"},
    {"김근호", 25 , "의사"},
    {"김세연", 30, "변호사"}
], columns=['name', 'age', 'job'])

# %%
df1
# Out:
#   name  age    job
# 0  송종천   20  프로그래머
# 1   의사   25    김근호
# 2  김세연  변호사     30

# %% [markdown]
# # 위의 두개는 스타일의 차이라
# # 쓰고싶은대로 쓰면된다.
#
#
#   - Pandas에서 row 는 index라고 부른다

# %%
df.index = ['학생1','학생2','학생3']

# %%
df
# Out:
#     name  age    job
# 학생1  송종천   20  프로그래머
# 학생2  김근호   25     의사
# 학생3  김세연   30    변호사

# %%
# drop은 무조건 삭제 delete ㄴㄴ
# drop을 해도 실제 데이터는 지워지지않지만
# inplace = True 를 주면 실제 데이터도 지워진다

# %%
# 행 추가 
# ex.loc[새 index명]  = data

# %%
df =pd.DataFrame({
    "국어" : [80,90,100],
    "영어" : [66,77,88],
    "수학" : [99,88,77]
})

# %%
df.index = ["송종천",'김근호','김세연']

# %%
df
# Out:
#       국어  영어  수학
# 송종천   80  66  99
# 김근호   90  77  88
# 김세연  100  88  77

# %%
df.loc["합계"] = df.sum(axis=0)

# %%
df["합계"] = df.sum(axis=1)

# %%
df
# Out:
#       국어  영어  수학   합계
# 송종천   80  66  99  245
# 김근호   90  77  88  255
# 김세연  100  88  77  265
# 정원준   95  95  95  285
# 변해성   80  80  80  240

# %% [markdown]
# df.loc
# loc는 일종의 location

# %%
df.loc['송종천','수학']
# Out:
# 99

# %%
df.loc["평균"] = df.a

# %%
df.loc["평균"] = df.loc['합계']/3

# %%
df
# Out:
#         국어     영어     수학     합계
# 송종천   80.0   66.0   99.0  245.0
# 김근호   90.0   77.0   88.0  255.0
# 김세연  100.0   88.0   77.0  265.0
# 합계   270.0  231.0  264.0  765.0
# 평균    90.0   77.0   88.0  255.0

# %%
# df.loc['송종천'] = [80,80,99]
df.drop(columns = "합계", inplace=True)

# %%
df.loc['송종천']= [80,80,99]

# %%
df
# Out:
#         국어     영어     수학
# 송종천   80.0   80.0   99.0
# 김근호   90.0   77.0   88.0
# 김세연  100.0   88.0   77.0
# 합계   270.0  231.0  264.0
# 평균    90.0   77.0   88.0

# %%
df.loc['송종천','국어'] = 90
#저 위치만 바뀌는거라 합계는 바뀌지않아서 업데이트를 해줘야 한다

# %%
df.loc['합계'] = df.sum(axis=0)

# %%
df
# Out:
#         국어     영어     수학
# 송종천   90.0   80.0   99.0
# 김근호   90.0   77.0   88.0
# 김세연  100.0   88.0   77.0
# 합계   640.0  553.0  616.0
# 평균    90.0   77.0   88.0

# %%
df.iloc[1,1] = 100

# %%
df
# Out:
#         국어     영어     수학
# 송종천   90.0   80.0   99.0
# 김근호   90.0  100.0   88.0
# 김세연  100.0   88.0   77.0
# 합계   640.0  553.0  616.0
# 평균    90.0   77.0   88.0

# %%
df.iloc[[0,2],[1,2]]
# Out:
#        영어    수학
# 송종천  80.0  99.0
# 김세연  88.0  77.0

# %%
#열 indexing: DataFrame 객체[column명] 또는 DataFrane객체.column명

# %%
df
# Out:
#         국어     영어     수학
# 송종천   90.0   80.0   99.0
# 김근호   90.0  100.0   88.0
# 김세연  100.0   88.0   77.0
# 합계   640.0  553.0  616.0
# 평균    90.0   77.0   88.0

# %%
df.loc["정원준"] = [95,95,95]

# %%
df
# Out:
#         국어     영어     수학
# 송종천   90.0   80.0   99.0
# 김근호   90.0  100.0   88.0
# 김세연  100.0   88.0   77.0
# 합계   640.0  553.0  616.0
# 평균    90.0   77.0   88.0
# 정원준   95.0   95.0   95.0

# %%
df =pd.DataFrame({
    "국어" : [80,90,100],
    "영어" : [66,77,88],
    "수학" : [99,88,77]
})

# %%
df.loc["정원준"] = [95,95,95]

# %%
df.loc["변해성"] = [80,80,80]

# %%
df
# Out:
#       국어  영어  수학
# 0     80  66  99
# 1     90  77  88
# 2    100  88  77
# 정원준   95  95  95
# 변해성   80  80  80

# %%
df.index = ["송종천",'김근호','김세연','정원준','변해성']

# %%
df
# Out:
#       국어  영어  수학
# 송종천   80  66  99
# 김근호   90  77  88
# 김세연  100  88  77
# 정원준   95  95  95
# 변해성   80  80  80

# %%
df[df.영어 >85] #특정점수이상 추출
# df.영어 > 85 만 쓰면
# Out:
#       국어  영어  수학
# 김세연  100  88  77
# 정원준   95  95  95

# %%
df > 90
# Out:
#         국어     영어     수학
# 송종천  False  False   True
# 김근호  False  False  False
# 김세연   True  False  False
# 정원준   True   True   True
# 변해성  False  False  False

# %%
df[df>90] # NaN 은 Not a Number의 약자이다.
# Out:
#         국어    영어    수학
# 송종천    NaN   NaN  99.0
# 김근호    NaN   NaN   NaN
# 김세연  100.0   NaN   NaN
# 정원준   95.0  95.0  95.0
# 변해성    NaN   NaN   NaN

# %%
df.sort_index()
# Out:
#       국어  영어  수학
# 김근호   90  77  88
# 김세연  100  88  77
# 변해성   80  80  80
# 송종천   80  66  99
# 정원준   95  95  95

# %%
df.sort_values(by = '수학')
# Out:
#       국어  영어  수학
# 김세연  100  88  77
# 변해성   80  80  80
# 김근호   90  77  88
# 정원준   95  95  95
# 송종천   80  66  99
